# %%
# %sql
CREATE CATALOG IF NOT EXISTS mlops_dbx_talk_dev;
CREATE CATALOG IF NOT EXISTS mlops_dbx_talk_test;
CREATE CATALOG IF NOT EXISTS mlops_dbx_talk_staging;
CREATE CATALOG IF NOT EXISTS mlops_dbx_talk_prod;

CREATE SCHEMA IF NOT EXISTS mlops_dbx_talk_dev.churn;
CREATE SCHEMA IF NOT EXISTS mlops_dbx_talk_test.churn;
CREATE SCHEMA IF NOT EXISTS mlops_dbx_talk_staging.churn;
CREATE SCHEMA IF NOT EXISTS mlops_dbx_talk_prod.churn;

# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()
w.workspace.mkdirs("/Shared/mlops_talk")
